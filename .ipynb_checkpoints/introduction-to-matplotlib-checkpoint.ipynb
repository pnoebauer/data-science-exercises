# %% [markdown]
# # Introduction to Matplotlib

# %% [markdown]
# <a href='https://realpython.com/python-matplotlib-guide/'>Matplotlib Guide</a>

# %%
# plots to be in the notebook
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot(); # semicolon to not plot the data output []

# %%
plt.plot()
plt.show() # same as using the semicolon (example above)

# %%
x = [1,2,3]
y = [10, 15, 20]
plt.plot(x, y);

# %% [markdown]
# ## Matplotlib Object Hierachy
# You can think of the Figure object as a box-like container holding one or more Axes (actual plots). Below the Axes in the hierarchy are smaller objects such as tick marks, individual lines, legends, and text boxes. Almost every “element” of a chart is its own manipulable Python object, all the way down to the ticks and labels:
# ![](figure-object.webp)

# %% [markdown]
# ### Anatomy of a Figure
# ![](matplotlib-anatomy-of-a-plot.png)

# %% [markdown]
# ## Methods for creating a figure

# %%
# Method 0
plt.plot();

# %%
# Method 1
fig = plt.figure() # creates figure
ax = fig.add_subplot() # adds axes
ax.plot(x, y) # add data
plt.show()

# %%
# Method 2
fig = plt.figure() # creates figure
ax = fig.add_axes([1, 1, 1, 1]) # add axes 
ax.plot(x, y) # add data
plt.show()

# %%
# Method 3 (recommended)
fig, ax = plt.subplots()
ax.plot(x, y) # add data
plt.show()

# %%
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ## Matplotlib Example Workflow

# %%
# 0. Import matplotlib and get it ready for Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [10, 20, 50, 100]

# 2. Setup plot
fix, ax = plt.subplots(figsize = (10, 5)) # create subplot with a width of 20 and height of 10

# 3. Plot data
ax.plot(x, y)

# 4. Customise plot
ax.set(title='Simple Plot',
      xlabel='x-axis',
      ylabel='y-axis')

# Save & show
fig.savefig('numpy-images/sample-plot.png')

# %% [markdown]
# ## Making Figures with NumPy Arrays
#
# Types of plots to be created:
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
# Create data
x = np.linspace(0, 10, 100, endpoint=False) # same as np.arange(0, 10, 10/100)
x[:5]
# Out:
# array([0. , 0.1, 0.2, 0.3, 0.4])

# %%
# Plot the data in a line plot
fix, ax = plt.subplots()
ax.plot(x, np.exp(x));

# %%
# Plot the data in a scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# Make plot from dictionary
nut_butter_prices = {'Almond butter': 10,
                     'Peanut butter': 8,
                     'Cashew butter': 12}

# Plot the data in a bar plot
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax.set(title='Nut Butter Store',
       ylabel='$ Price'
       );

# %%
# Plot the data in a horizontal bar plot
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
ax.set(title='Nut Butter Store',
       xlabel='$ Price');

# %%
# Make random data from the normal distribution
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x, 50); # create historgram with 50 bins

# %% [markdown]
# ## Two Options For Subplots

# %%
# Option #1: unpack the axes
# If more than one row and column are created, ax will be a tuple of tuples
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2,
                                             figsize=(10,5))
np.random.seed(0)

ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000));

# %%
# Option #2: use an axes array
fig, ax = plt.subplots(ncols=2,
                       nrows=2,
                       figsize=(10,5))
np.random.seed(0)
# Plot to each different index [rowIndex, columnIndex]
ax[0, 0].plot(x, x/2)
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(np.random.randn(1000));

# %%
# Only plot 2 subplots (option #1)
# If n rows or columns are created, ax is an n-tuple
fig, (ax1, ax2) = plt.subplots(ncols=2)
ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10));

# %% [markdown]
# # Plotting From Pandas DataFrames

# %%
import pandas as pd

# %%
# Make a dataframe
car_sales = pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# convert prices to integers
car_sales['Price'] = car_sales['Price'].str.replace('$', '')
car_sales['Price'] = car_sales['Price'].str.replace(',', '')
car_sales['Price'] = car_sales['Price'].str.replace('.', '')
car_sales['Price'] = car_sales['Price'].astype(int)
car_sales['Price'] = (car_sales['Price']/100).astype(int)
car_sales['Price']
# Out:
# <ipython-input-52-8f9153bad900>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   car_sales['Price'] = car_sales['Price'].str.replace('$', '')
# <ipython-input-52-8f9153bad900>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   car_sales['Price'] = car_sales['Price'].str.replace('.', '')
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int64

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2021', periods=1000))
ts
# Out:
# 2021-01-01    0.985318
# 2021-01-02    0.766920
# 2021-01-03    0.402626
# 2021-01-04   -1.775888
# 2021-01-05    1.669251
#                 ...
# 2023-09-23    0.210359
# 2023-09-24   -0.005927
# 2023-09-25    1.366060
# 2023-09-26    1.555114
# 2023-09-27    0.613326
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot();

# %%
tsCumsum = ts.cumsum()
tsCumsum.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales2 = pd.read_csv('car-sales.csv')
car_sales2['Price'] = car_sales2['Price'].str.replace('[/$/,/.]','')
car_sales2['Price']
# Out:
# <ipython-input-64-df099711b16d>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales2['Price'] = car_sales2['Price'].str.replace('[/$/,/.]','')
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: object

# %%
# returns a string
type(car_sales2['Price'][0])
# Out:
# str

# %%
# slicing the object returns a series object (note: [:1] is equivalent to [slice(1)])
car_sales2['Price'][slice(2)]
car_sales2['Price'][:2]
# Out:
# 0    400000
# 1    500000
# Name: Price, dtype: object

# %%
type(car_sales2['Price'][:2])
# Out:
# pandas.core.series.Series

# %%
# won't work because it is a string: car_sales2['Price'][0].str[:-2]
# .str only works on series objects
# remove last two characters
car_sales2['Price'][:2].str[:-2]
# Out:
# 0    4000
# 1    5000
# Name: Price, dtype: object

# %%
# remove last two characters of entire series
car_sales2['Price'] = car_sales2['Price'].str[:-2]
